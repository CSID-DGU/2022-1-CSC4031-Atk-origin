# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tokenizers
# !python -m nltk.downloader stopwords
# Out:
# Collecting tokenizers
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 5.5 MB/s
# Installing collected packages: tokenizers
# Successfully installed tokenizers-0.11.6
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.trainers import BpeTrainer
from collections import Counter
from nltk.corpus import stopwords

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
tokenizer = Tokenizer(BPE())
tokenizer.pre_tokenizer = Whitespace()
trainer = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"])
tokenizer.train(files=["wiki.train.raw", "wiki.valid.raw", "wiki.test.raw"], trainer=trainer)

# %%
f = open("test.txt", 'r')
string = ''
for _line in f.readlines():
    string += _line
sig = [',', '.', '(', ')', '-']
stop_words = stopwords.words('english')
for i in sig:
    stop_words.append(i)

# %%
output = tokenizer.encode(string)
result = []
for w in output.tokens:
    if w not in stop_words:
        result.append(w)

# %%
print(result)
print(Counter(result).most_common(10))
# Out:
# ['Bab', 'ies', 'world', 'every', 'kind', 'society', 'alike', 'needs', 'leads', 'certain', 'universal', 'quality', 'child', 'aring', 'practices', 'However', 'society', 'expect', 'demands', 'different', 'behaviors', 'members', 'differences', 'lead', 'variations', 'child', 'aring', 'The', 'way', 'society', 'chooses', 'rear', 'young', 'reveals', 'goals', 'purposes', 'Jan', 'eway', '1975', 'Wolf', 'enstein', '1953', 'described', 'evolution', 'advice', 'In', 'fant', 'Care', 'Bullet', 'nine', 'print', 'ings', '1914', '1951', 'In', '1914', 'thumb', 'suck', 'ing', 'mast', 'urb', 'ation', 'dealt', 'extreme', 'harsh', 'methods', '1951', 'behaviors', 'thought', 'minor', 'problems', 'could', 'ignored', 'Wh', 'iting', 'suggested', 'child', 'aring', 'practices', 'dependent', 'upon', 'maintenance', 'systems', 'society', 'Wh', 'iting', '&', 'Child', '1953', 'hypothe', 'sized', 'cr', 'ises', 'culture', 'met', 'changes', 'social', 'structure', 'influence', 'child', 'aring', 'practices', 'Wh', 'iting', 'Chad', 'si', 'Anton', 'ovsky', '&', 'Ay', 'res', '1966', 'The', 'influences', 'society', 'life', 'mother', 'seen', 'important', 'factors', 'methods', 'practices', 'child', 'aring', 'S', 'ears', 'Mac', 'co', 'L', 'evin', '1957', 'More', '25', 'years', 'ago', 'mothers', 'interviewed', 'concerning', 'child', 'aring', 'practices', 'Robert', 'R', 'S', 'ears', 'Eleanor', 'E', 'Mac', 'co', 'Harry', 'L', 'evin', 'In', '1957', 'approximately', 'six', 'years', 'beginning', 'study', 'results', 'published', 'Patter', 'ns', 'Child', 'Rear', 'ing', 'The', 'authors', 'concerned', 'three', 'questions', ':', 'How', 'parents', 'raise', 'children', '?', 'How', 'particular', 'practices', 'affect', 'certain', 'behaviors', '?', 'What', 'leads', 'mother', 'use', 'one', 'method', 'rather', 'another', '?', 'The', '1957', 'Patter', 'ns', 'study', 'showed', 'child', 'aring', 'diverse', 'activity', 'The', 'great', 'variety', 'methods', 'techniques', 'one', 'major', 'findings', 'study', 'How', 'today', "'", 'parents', 'raise', 'children', '?', 'That', 'question', 'prompted', 'attempt', 'repl', 'icate', 'extend', 'Patter', 'ns', 'Child', 'Rear', 'ing', 'The', 'present', 'report', 'focuses', 'mainly', 'repl', 'ication', 'aspect', 'using', 'mother', 'interviews', 'Two', 'studies', 'related', 'originating', 'one', 'near', 'ing', 'completion', 'another', 'planning', 'stage', 'These', 'studies', 'involve', 'interviews', 'children', 'fathers', 'grand', 'mothers', 'represent', 'extension', 'original', 'Patter', 'ns', 'study', 'beyond', 'mother', 'interviews', 'When', 'work', 'completed', 'time', 'yet', 'presentation', 'findings', 'probably', 'require', 'book', 'length', 'manuscript', 'Therefore', 'decided', 'use', 'thesis', 'means', 'providing', 'introduction', 'view', 'repl', 'ication', 'effort', 'related', 'studies', 'report', 'principal', 'findings', 'mother', 'interviews', 'This', 'thesis', 'format', 'represents', 'devi', 'ation', 'usual', 'Gradu', 'ate', 'College', 'style', 'Em', 'bed', 'ded', 'within', 'thesis', 'effect', 'complete', 'manuscript', 'prepared', 'submission', 'technical', 'journal', 'accordance', 'Publication', 'Man', 'ual', 'American', 'Psych', 'ological', 'Association', 'Second', 'Edition', 'The', 'manuscript', 'forms', 'body', 'thesis', 'pages', '5', '25', 'thesis', 'constitut', 'ing', 'manuscript', 'The', 'purposes', 'functions', 'manuscript', 'thesis', 'somewhat', 'different', 'A', 'thesis', 'often', 'contains', 'variety', 'information', 'data', 'materials', 'typically', 'would', 'included', 'manuscript', 'submitted', 'publication', 'To', 'make', 'thesis', 'complete', 'items', 'inserted', 'A', 'ck', 'led', 'g', 'ments', 'Intro', 'duction', 'Ap', 'pend', 'ices', 'end', 'Thus', 'hope', 'format', 'offer', 'advantages', 'reader', 'authors', 'ultimately', 'discipline', 'without', 'corresponding', 'loss', 'strengths', 'traditional', 'thesis', 'format', 'In', 'early', '1950s', 'Robert', 'R', 'S', 'ears', 'Eleanor', 'E', 'Mac', 'co', 'Harry', 'L', 'evin', 'undertook' ...
# [('child', 30), ('aring', 24), ('practices', 19), ('The', 16), ('study', 16), ('children', 16), ('mothers', 14), ('Patter', 13), ('ns', 13), ('S', 11)]
